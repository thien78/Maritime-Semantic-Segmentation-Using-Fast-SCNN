# %%
# CELL1: Import các thư viện cần thiết
import os
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.models.segmentation import lraspp_mobilenet_v3_large
import albumentations as A
from albumentations.pytorch import ToTensorV2
from albumentations import Compose, Resize, Normalize
import matplotlib.pyplot as plt
from tqdm import tqdm
from torch.cuda.amp import autocast, GradScaler  # Mixed precision training

# %%
# CELL2: Dataset class
class LaRSDataset(Dataset):
    def __init__(self, root_dir, split='train', transform=None):
        self.image_dir = os.path.join(root_dir, 'images', split, 'images')
        self.mask_dir = os.path.join(root_dir, 'annotations', 'semantic', split, 'semantic_masks')
        self.image_files = sorted([f for f in os.listdir(self.image_dir) if f.endswith('.jpg')])
        self.transform = transform

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_name = self.image_files[idx]
        image_path = os.path.join(self.image_dir, img_name)
        mask_path = os.path.join(self.mask_dir, img_name.replace('.jpg', '.png'))

        image = np.array(Image.open(image_path).convert('RGB'))
        mask = np.array(Image.open(mask_path)).astype(np.uint8)
        mask[mask > 2] = 255  # Set any class > 2 to ignore index (255)

        if self.transform:
            transformed = self.transform(image=image, mask=mask)
            image = transformed['image']
            mask = transformed['mask']

        return image, mask.long()

# %%
# CELL3: Data preparation
# Cấu hình transform dùng chung
transform = Compose([
    Resize(320, 320),
    Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    ToTensorV2()
])

# Dataset
train_dataset = LaRSDataset("data/lars", split="train", transform=transform)
val_dataset = LaRSDataset("data/lars", split="val", transform=transform)

# DataLoader
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=0, drop_last=True) 
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False, num_workers=0, drop_last=True)

# %%
# CELL4: Model definition
def get_model(num_classes=3):
    # Load pretrained MobileNetV3 with LR-ASPP
    model = lraspp_mobilenet_v3_large(pretrained=True)
    
    # Modify the classifier heads for our number of classes
    # Low-level features classifier
    model.classifier.low_classifier = nn.Conv2d(40, num_classes, kernel_size=1)
    # High-level features classifier
    model.classifier.high_classifier = nn.Conv2d(128, num_classes, kernel_size=1)
    
    return model

# %%
def train_model(model, train_loader, val_loader, num_epochs=30, device='cuda'):
    # Khởi tạo model và các thành phần huấn luyện
    model = model.to(device)
    
    # Sử dụng AdamW với weight decay
    optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)
    
    # Scheduler cosine với warmup
    scheduler = optim.lr_scheduler.OneCycleLR(
        optimizer,
        max_lr=0.01,
        epochs=num_epochs,
        steps_per_epoch=len(train_loader),
        pct_start=0.1
    )
    
    criterion = nn.CrossEntropyLoss(ignore_index=255)
    
    # Khởi tạo gradient scaler cho mixed precision
    scaler = torch.cuda.amp.GradScaler()
    
    # Theo dõi các metrics
    best_val_loss = float('inf')
    best_miou = 0.0
    early_stop_counter = 0
    patience = 5
    
    train_losses = []
    val_losses = []
    val_mious = []
    
    for epoch in range(num_epochs):
        model.train()
        epoch_train_loss = 0.0
        
        # Training loop với progress bar
        for images, masks in tqdm(train_loader, desc=f'Epoch {epoch+1}/{num_epochs}'):
            images = images.to(device, non_blocking=True)
            masks = masks.to(device, non_blocking=True)
            
            # Zero gradient
            optimizer.zero_grad(set_to_none=True)  # Tối ưu memory
            
            # Forward pass với mixed precision
            with torch.cuda.amp.autocast():
                outputs = model(images)['out']
                loss = criterion(outputs, masks)
            
            # Backward pass với gradient scaling
            scaler.scale(loss).backward()
            
            # Gradient clipping
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            
            # Cập nhật weights
            scaler.step(optimizer)
            scaler.update()
            
            # Cập nhật learning rate
            scheduler.step()
            
            epoch_train_loss += loss.item()
        
        # Tính toán average training loss
        avg_train_loss = epoch_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        
        # Validation phase
        model.eval()
        val_loss = 0.0
        total_pixels = 0
        correct_pixels = 0
        
        with torch.no_grad():
            for images, masks in val_loader:
                images = images.to(device, non_blocking=True)
                masks = masks.to(device, non_blocking=True)
                
                # Forward pass với mixed precision
                with torch.cuda.amp.autocast():
                    outputs = model(images)['out']
                    loss = criterion(outputs, masks)
                
                val_loss += loss.item()
                
                # Tính toán accuracy
                _, preds = torch.max(outputs, 1)
                valid_mask = (masks != 255)  # Bỏ qua ignore index
                correct_pixels += torch.sum(preds[valid_mask] == masks[valid_mask]).item()
                total_pixels += torch.sum(valid_mask).item()
        
        avg_val_loss = val_loss / len(val_loader)
        val_losses.append(avg_val_loss)
        
        # Tính mean IoU
        val_accuracy = correct_pixels / total_pixels if total_pixels > 0 else 0
        val_mious.append(val_accuracy)
        
        print(f'Epoch {epoch+1}/{num_epochs}: '
              f'Train Loss: {avg_train_loss:.4f}, '
              f'Val Loss: {avg_val_loss:.4f}, '
              f'Val mIoU: {val_accuracy:.4f}')
        
        # Lưu model tốt nhất dựa trên val loss
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            torch.save(model.state_dict(), 'best_mobilenetv3.pth')
            print(f'New best model saved with val loss: {best_val_loss:.4f}')
            early_stop_counter = 0
        else:
            early_stop_counter += 1
        
        # Lưu model tốt nhất dựa trên mIoU
        if val_accuracy > best_miou:
            best_miou = val_accuracy
            torch.save(model.state_dict(), 'best_miou_mobilenetv3.pth')
            print(f'New best mIoU model saved with mIoU: {best_miou:.4f}')
        
        # Early stopping
        if early_stop_counter >= patience:
            print(f'Early stopping at epoch {epoch+1}')
            break
    
    # Plot training curves
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(val_mious, label='Validation mIoU', color='green')
    plt.xlabel('Epoch')
    plt.ylabel('mIoU')
    plt.legend()
    
    plt.suptitle('Training Metrics')
    plt.savefig('bieudo_mobilenetv3.png')
    plt.close()
    
    print('Training complete')
    print(f'Best Validation Loss: {best_val_loss:.4f}')
    print(f'Best Validation mIoU: {best_miou:.4f}')
    
    return model

# %%
# Check for GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
    
# Initialize model
model = get_model(num_classes=3)
# Out:
# Using device: cuda
# C:\Users\ADMIN\Documents\UIT school\HK6\AI - Embedded\DEMO\lib_virtual\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\ADMIN\Documents\UIT school\HK6\AI - Embedded\DEMO\lib_virtual\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=LRASPP_MobileNet_V3_Large_Weights.COCO_WITH_VOC_LABELS_V1`. You can also use `weights=LRASPP_MobileNet_V3_Large_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Train the model
trained_model = train_model(
    model, 
    train_loader, 
    val_loader, 
    num_epochs=30, 
    device=device
)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_35156\2299174393.py:20: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# Epoch 1/30:   0%|                                                                              | 0/651 [00:00<?, ?it/s]C:\Users\ADMIN\AppData\Local\Temp\ipykernel_35156\2299174393.py:45: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch 1/30: 100%|████████████████████████████████████████████████████████████████████| 651/651 [02:34<00:00,  4.21it/s]
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_35156\2299174393.py:81: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch 1/30: Train Loss: 0.1257, Val Loss: 0.3751, Val mIoU: 0.9148
# New best model saved with val loss: 0.3751
# New best mIoU model saved with mIoU: 0.9148
# Epoch 2/30: 100%|████████████████████████████████████████████████████████████████████| 651/651 [01:22<00:00,  7.92it/s]
# Epoch 2/30: Train Loss: 0.1339, Val Loss: 0.6273, Val mIoU: 0.8317
# Epoch 3/30: 100%|████████████████████████████████████████████████████████████████████| 651/651 [01:16<00:00,  8.52it/s]
# Epoch 3/30: Train Loss: 0.1330, Val Loss: 0.2672, Val mIoU: 0.9007
# New best model saved with val loss: 0.2672
# Epoch 4/30: 100%|████████████████████████████████████████████████████████████████████| 651/651 [01:34<00:00,  6.88it/s]
# Epoch 4/30: Train Loss: 0.1214, Val Loss: 0.1712, Val mIoU: 0.9350
# New best model saved with val loss: 0.1712
# New best mIoU model saved with mIoU: 0.9350
# Epoch 5/30: 100%|████████████████████████████████████████████████████████████████████| 651/651 [01:28<00:00,  7.36it/s]
# Epoch 5/30: Train Loss: 0.1119, Val Loss: 0.1996, Val mIoU: 0.9247
# Epoch 6/30: 100%|████████████████████████████████████████████████████████████████████| 651/651 [01:16<00:00,  8.56it/s]
# Epoch 6/30: Train Loss: 0.1016, Val Loss: 0.1388, Val mIoU: 0.9494
# New best model saved with val loss: 0.1388
# New best mIoU model saved with mIoU: 0.9494
# Epoch 7/30: 100%|████████████████████████████████████████████████████████████████████| 651/651 [01:16<00:00,  8.56it/s]
# Epoch 7/30: Train Loss: 0.1035, Val Loss: 0.1505, Val mIoU: 0.9436
# Epoch 8/30: 100%|████████████████████████████████████████████████████████████████████| 651/651 [01:15<00:00,  8.57it/s]
# Epoch 8/30: Train Loss: 0.0994, Val Loss: 0.1869, Val mIoU: 0.9237
# Epoch 9/30: 100%|████████████████████████████████████████████████████████████████████| 651/651 [01:16<00:00,  8.54it/s]
# Epoch 9/30: Train Loss: 0.0905, Val Loss: 0.1909, Val mIoU: 0.9274
# Epoch 10/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:15<00:00,  8.58it/s]
# Epoch 10/30: Train Loss: 0.0814, Val Loss: 0.2002, Val mIoU: 0.9212
# Epoch 11/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:17<00:00,  8.37it/s]
# Epoch 11/30: Train Loss: 0.0830, Val Loss: 0.1332, Val mIoU: 0.9488
# New best model saved with val loss: 0.1332
# Epoch 12/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:15<00:00,  8.58it/s]
# Epoch 12/30: Train Loss: 0.0654, Val Loss: 0.1240, Val mIoU: 0.9529
# New best model saved with val loss: 0.1240
# New best mIoU model saved with mIoU: 0.9529
# Epoch 13/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:16<00:00,  8.52it/s]
# Epoch 13/30: Train Loss: 0.0739, Val Loss: 0.1286, Val mIoU: 0.9491
# Epoch 14/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:16<00:00,  8.50it/s]
# Epoch 14/30: Train Loss: 0.0648, Val Loss: 0.1277, Val mIoU: 0.9536
# New best mIoU model saved with mIoU: 0.9536
# Epoch 15/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:15<00:00,  8.58it/s]
# Epoch 15/30: Train Loss: 0.0647, Val Loss: 0.1386, Val mIoU: 0.9463
# Epoch 16/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:17<00:00,  8.41it/s]
# Epoch 16/30: Train Loss: 0.0523, Val Loss: 0.1128, Val mIoU: 0.9594
# New best model saved with val loss: 0.1128
# New best mIoU model saved with mIoU: 0.9594
# Epoch 17/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:16<00:00,  8.51it/s]
# Epoch 17/30: Train Loss: 0.0485, Val Loss: 0.1208, Val mIoU: 0.9535
# Epoch 18/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:16<00:00,  8.53it/s]
# Epoch 18/30: Train Loss: 0.0506, Val Loss: 0.0910, Val mIoU: 0.9638
# New best model saved with val loss: 0.0910
# New best mIoU model saved with mIoU: 0.9638
# Epoch 19/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:16<00:00,  8.55it/s]
# Epoch 19/30: Train Loss: 0.0465, Val Loss: 0.0972, Val mIoU: 0.9644
# New best mIoU model saved with mIoU: 0.9644
# Epoch 20/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:16<00:00,  8.54it/s]
# Epoch 20/30: Train Loss: 0.0424, Val Loss: 0.0806, Val mIoU: 0.9690
# New best model saved with val loss: 0.0806
# New best mIoU model saved with mIoU: 0.9690
# Epoch 21/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:15<00:00,  8.59it/s]
# Epoch 21/30: Train Loss: 0.0404, Val Loss: 0.0832, Val mIoU: 0.9685
# Epoch 22/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:16<00:00,  8.56it/s]
# Epoch 22/30: Train Loss: 0.0385, Val Loss: 0.0744, Val mIoU: 0.9720
# New best model saved with val loss: 0.0744
# New best mIoU model saved with mIoU: 0.9720
# Epoch 23/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:15<00:00,  8.61it/s]
# Epoch 23/30: Train Loss: 0.0382, Val Loss: 0.0838, Val mIoU: 0.9690
# Epoch 24/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:15<00:00,  8.59it/s]
# Epoch 24/30: Train Loss: 0.0364, Val Loss: 0.0833, Val mIoU: 0.9694
# Epoch 25/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:15<00:00,  8.58it/s]
# Epoch 25/30: Train Loss: 0.0358, Val Loss: 0.0788, Val mIoU: 0.9717
# Epoch 26/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:14<00:00,  8.71it/s]
# Epoch 26/30: Train Loss: 0.0345, Val Loss: 0.0842, Val mIoU: 0.9701
# Epoch 27/30: 100%|███████████████████████████████████████████████████████████████████| 651/651 [01:14<00:00,  8.68it/s]
# Epoch 27/30: Train Loss: 0.0335, Val Loss: 0.0855, Val mIoU: 0.9700
# Early stopping at epoch 27
# Training complete
# Best Validation Loss: 0.0744
# Best Validation mIoU: 0.9720

# %%
# Save final model
torch.save(trained_model.state_dict(), 'final_mobilenetv3.pth')

# %%
# Load model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = get_model(num_classes=3)
model.load_state_dict(torch.load("best_mobilenetv3.pth", map_location=device))
model.to(device)
model.eval()

# %%
# Cell 1: Chuyển từ mô hình PyTorch sang ONNX
import torch
import torch.nn as nn
from torchvision.models.segmentation import lraspp_mobilenet_v3_large

model = get_model(num_classes=3)
model.load_state_dict(torch.load("best_mobilenetv3.pth", map_location=torch.device('cpu')))
model.eval()

# Dummy input (BCHW)
dummy_input = torch.randn(1, 3, 320, 320)
torch.onnx.export(model, dummy_input, "lraspp_mobilenetv3.onnx",
                  input_names=['input'], output_names=['output'],
                  opset_version=11)
print("✅ Đã xuất lraspp_mobilenetv3.onnx")
# Out:
# ✅ Đã xuất lraspp_mobilenetv3.onnx

# %%
# Cell 2: Chuyển ONNX → TensorFlow SavedModel
# !onnx-tf convert -i lraspp_mobilenetv3.onnx -o model_saved
# Out:
# C:\Users\ADMIN\Documents\UIT school\HK6\AI - Embedded\DEMO\lib_virtual\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2025-06-08 17:32:23,371 - onnx-tf - INFO - Start converting onnx pb to tf saved model
# WARNING:absl:Found untraced functions such as gen_tensor_dict while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 2025-06-08 17:32:31,966 - onnx-tf - INFO - Converting completes successfully.
# INFO:onnx-tf:Converting completes successfully.

# %%
# Cell 3: Representative dataset từ tập val
import os
import numpy as np
from PIL import Image
import torchvision.transforms as T
import tensorflow as tf

def representative_data_gen():
    image_dir = "data/lars/images/val/images"
    image_files = [os.path.join(image_dir, f) for f in os.listdir(image_dir) if f.endswith(".jpg")]

    preprocess = T.Compose([
        T.Resize((320, 320)),
        T.ToTensor(),
        T.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
    ])

    for path in image_files[:100]:
        img = Image.open(path).convert("RGB")
        img = preprocess(img)
        img = img.unsqueeze(0).numpy().astype(np.float32)
        yield [img]

# %%
# Cell 4: Convert SavedModel → .tflite INT8
converter = tf.lite.TFLiteConverter.from_saved_model("model_saved")
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.uint8
converter.inference_output_type = tf.uint8

int8_tflite_model = converter.convert()

with open("lraspp_mobilenetv3_int8.tflite", "wb") as f:
    f.write(int8_tflite_model)

print("✅ Đã tạo lraspp_mobilenetv3_int8.tflite")
# Out:
# ✅ Đã tạo lraspp_mobilenetv3_int8.tflite

# %%
interpreter = tf.lite.Interpreter(model_path="lraspp_mobilenetv3_int8.tflite")
interpreter.allocate_tensors()
input_type = interpreter.get_input_details()[0]['dtype']
output_type = interpreter.get_output_details()[0]['dtype']
print("Input type:", input_type)
print("Output type:", output_type)
# Out:
# Input type: <class 'numpy.uint8'>
# Output type: <class 'numpy.uint8'>

# %%
import torch
from torchvision.models.segmentation import lraspp_mobilenet_v3_large

# Khởi tạo mô hình
model = lraspp_mobilenet_v3_large(pretrained=False)

# Sửa lại đầu ra cho 3 lớp (background, water, sky)
model.classifier.low_classifier = torch.nn.Conv2d(40, 3, kernel_size=1)
model.classifier.high_classifier = torch.nn.Conv2d(128, 3, kernel_size=1)

# Tính tổng số tham số
total_params = sum(p.numel() for p in model.parameters())
print(f"Tổng số tham số: {total_params:,}")

# Kiểm tra có < 10 triệu tham số không
if total_params < 10_000_000:
    print("Mô hình có ít hơn 10 triệu tham số (đạt yêu cầu)")
else:
    print("Mô hình có nhiều hơn 10 triệu tham số")
# Out:
# Tổng số tham số: 3,218,478
# Mô hình có ít hơn 10 triệu tham số (đạt yêu cầu)
# C:\Users\ADMIN\Documents\UIT school\HK6\AI - Embedded\DEMO\lib_virtual\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\ADMIN\Documents\UIT school\HK6\AI - Embedded\DEMO\lib_virtual\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
import tensorflow as tf

# Load model TFLite
interpreter = tf.lite.Interpreter(model_path="lraspp_mobilenetv3_int8.tflite")
interpreter.allocate_tensors()

# Đếm tổng số tham số
total_params = 0
for tensor in interpreter.get_tensor_details():
    if 'shape' in tensor and tensor['dtype'] in (tf.float32, tf.int8, tf.uint8):
        total_params += np.prod(tensor['shape'])

print(f"Tổng số tham số: {total_params:,}")
# Out:
# Tổng số tham số: 68,795,910

# %%
import tensorflow as tf
import numpy as np

interpreter = tf.lite.Interpreter(model_path="lraspp_mobilenetv3_int8.tflite")
interpreter.allocate_tensors()
tensor_details = interpreter.get_tensor_details()

# Lọc các tensor có tên chứa Conv hoặc depthwise, thường là trọng số
weight_like_tensors = [
    t for t in tensor_details
    if ('Conv' in t['name'] or 'depthwise' in t['name'])
    and np.prod(t['shape']) > 1
    and t['dtype'] in (np.int8, np.uint8)
]

total_weight_params = sum(np.prod(t['shape']) for t in weight_like_tensors)

print(f"Approx number of weight params: {total_weight_params:,}")
print("Sample tensor names:")
for t in weight_like_tensors[:10]:
    print(f"- {t['name']}, shape={t['shape']}")
# Out:
# Approx number of weight params: 5,557,208
# Sample tensor names:
# - depthwise_14, shape=[  1   5   5 960]
# - depthwise_13, shape=[  1   5   5 960]
# - depthwise_12, shape=[  1   5   5 672]
# - depthwise_11, shape=[  1   3   3 672]
# - depthwise_10, shape=[  1   3   3 480]
# - depthwise_9, shape=[  1   3   3 184]
# - depthwise_8, shape=[  1   3   3 184]
# - depthwise_7, shape=[  1   3   3 200]
# - depthwise_6, shape=[  1   3   3 240]
# - depthwise_5, shape=[  1   5   5 120]
