# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.models import mobilenet_v2
from torchvision.models._utils import IntermediateLayerGetter
from torchvision.models.segmentation.deeplabv3 import DeepLabHead
from albumentations import Compose, Resize, Normalize
from albumentations.pytorch import ToTensorV2
from PIL import Image
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import tensorflow as tf  # Cho phần xuất TFLite

# %%
# 🧾 Dataset xử lý Semantic Segmentation từ LaRS
class LaRSDataset(Dataset):
    def __init__(self, root_dir, split='train', transform=None):
        # Thư mục ảnh và mask tương ứng
        self.image_dir = os.path.join(root_dir, 'images', split, 'images')
        self.mask_dir = os.path.join(root_dir, 'annotations', 'semantic', split, 'semantic_masks')
        self.image_files = sorted([f for f in os.listdir(self.image_dir) if f.endswith('.jpg')])
        self.transform = transform

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        # Đọc ảnh và mask theo chỉ số
        img_name = self.image_files[idx]
        image_path = os.path.join(self.image_dir, img_name)
        mask_path = os.path.join(self.mask_dir, img_name.replace('.jpg', '.png'))

        image = np.array(Image.open(image_path).convert('RGB'))
        mask = np.array(Image.open(mask_path)).astype(np.uint8)
        mask[mask > 2] = 255  # Gán lớp không quan tâm (hoặc 'void') thành 255

        if self.transform:
            transformed = self.transform(image=image, mask=mask)
            image = transformed['image']
            mask = transformed['mask']

        return image, mask.long()

# %%
# 🏗️ Hàm tạo mô hình phân đoạn sử dụng MobileNetV2 làm backbone
def get_deeplab_model(num_classes):
    # Load mô hình MobileNetV2 pre-trained
    backbone = mobilenet_v2(pretrained=True).features
    backbone.out_channels = 1280

    # Đầu ra là DeepLabHead với số lớp tùy chỉnh
    classifier = DeepLabHead(1280, num_classes)

    model = nn.Sequential(
        backbone,
        nn.AdaptiveAvgPool2d((1, 1)),
        nn.Flatten(),
        nn.Linear(1280, num_classes)
    )
    return model

# %%
# 🔁 Hàm biến đổi ảnh sử dụng Albumentations
def get_transform():
    return Compose([
        Resize(256, 256),  # Resize ảnh về kích thước cố định
        Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
        ToTensorV2(),
    ])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = build_deeplabv3_mobilenetv2(num_classes=3, quantize=True).to(device)

# %%
# ⚙️ Cấu hình Optimizer và Loss
criterion = nn.CrossEntropyLoss(ignore_index=255)
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
train_model(
    model, 
    train_loader, 
    val_loader,
    num_epochs=2,
    save_path="best_qat_model.pth"
)
# Out:
# Epoch 1/2: 100%|█████████████████████████████████████████████████████████████████████| 325/325 [01:42<00:00,  3.17it/s]
# 📉 Epoch 1: Train Loss = 0.2121 | Val Loss = 0.1540
# ✅ Saved best model at epoch 1 → best_qat_model.pth
# Epoch 2/2: 100%|█████████████████████████████████████████████████████████████████████| 325/325 [01:48<00:00,  2.99it/s]
# 📉 Epoch 2: Train Loss = 0.1265 | Val Loss = 0.1551

# %%
# ✅ Export ONNX từ mô hình QAT (chưa convert)

#def export_qat_onnx(model, onnx_path="model_qat.onnx"):
#    import torch
#    model.eval()
#    device = next(model.parameters()).device
#    dummy_input = torch.randn(1, 3, 320, 320).to(device)
#    torch.onnx.export(
#        model,
#        dummy_input,
#        onnx_path,
#        input_names=["input"],
#        output_names=["output"],
#        opset_version=13
#    )
#    print(f"✅ Exported QAT ONNX tại: {onnx_path}")

def export_qat_onnx(model, onnx_path="model_qat.onnx"):
    import torch

    # ✅ Convert QAT → int8
    model.eval()
    model.cpu()
    

    dummy_input = torch.randn(1, 3, 320, 320)   #.to(torch.float32)  # float32 giữ nguyên

    # ⚠️ Bỏ FakeQuant modules thủ công (để tránh lỗi fused_moving_avg_obs_fake_quant)
    for name, module in model.named_modules():
        if hasattr(module, 'activation_post_process'):
            module.activation_post_process = torch.nn.Identity()

    torch.onnx.export(
        model,
        dummy_input,
        onnx_path,
        input_names=["input"],
        output_names=["output"],
        opset_version=13
    )
    print(f"✅ Exported QAT ONNX tại: {onnx_path}")

# %%
# 3. Export sang ONNX
export_qat_onnx(model)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[83], line 2
#       1 # 3. Export sang ONNX
# ----> 2 export_qat_onnx(model)
#
# Cell In[82], line 33, in export_qat_onnx(model, onnx_path)
#      30     if hasattr(module, 'activation_post_process'):
#      31         module.activation_post_process = torch.nn.Identity()
# ---> 33 torch.onnx.export(
#      34     model,
#      35     dummy_input,
#      36     onnx_path,
#      37     input_names=["input"],
#      38     output_names=["output"],
#      39     opset_version=13
#      40 )
#      41 print(f"✅ Exported QAT ONNX tại: {onnx_path}")
#
# ...

# %%
# 📤 Chuyển đổi mô hình sang TFLite (giả định đã convert sang ONNX trước)
converter = tf.lite.TFLiteConverter.from_saved_model('saved_model')
tflite_model = converter.convert()
with open('model.tflite', 'wb') as f:
    f.write(tflite_model)

# %%
# 4. Convert sang .tflite (INT8)
convert_qat_onnx_to_tflite("model_qat.onnx", image_dir="images")

# %%
# 🧪 Hàm đánh giá mô hình
def evaluate(model, loader, criterion, device):
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for images, masks in tqdm(loader):
            images, masks = images.to(device), masks.to(device)
            outputs = model(images)
            loss = criterion(outputs, masks)
            val_loss += loss.item()
    return val_loss / len(loader)

# %%
evaluate_full_metrics(model, val_dataset, num_classes=3, device=device)

# %%
def visualize_prediction(model, dataset, idx=0, device='cuda'):
    model.eval()
    image, mask = dataset[idx]
    image_tensor = image.unsqueeze(0).to(device)
    with torch.no_grad():
        output = model(image_tensor)['out']
        pred = torch.argmax(output, dim=1).squeeze().cpu().numpy()

    # ✅ Unnormalize ảnh
    img = image.permute(1, 2, 0).cpu().numpy()
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    img = (img * std + mean) * 255
    img = img.astype(np.uint8)
    
    gt = mask.cpu().numpy()

    def colorize(mask):
        colors = {
            0: (247, 195, 37),    # obstacle
            1: (41, 167, 224),    # water
            2: (90, 75, 164),     # sky
            255: (127, 127, 127)  # gray for ignored
        }
        out = np.zeros((*mask.shape, 3), dtype=np.uint8)
        for k, v in colors.items():
            out[mask == k] = v
        return out

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 3, 1); plt.imshow(img.astype(np.uint8)); plt.title("Original Photo")
    plt.subplot(1, 3, 2); plt.imshow(colorize(gt)); plt.title("Ground Truth")
    plt.subplot(1, 3, 3); plt.imshow(colorize(pred)); plt.title("Predict")
    plt.show()

# %%
visualize_prediction(model, val_dataset, idx=4)
